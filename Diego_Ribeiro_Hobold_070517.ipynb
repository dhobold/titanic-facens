# %% [markdown]
# # **Trabalho Final**
# ### Algoritmos e Programação com Linguagem Python
# ---
#
# **Orientações Gerais:**
#
# * Esta é o trabalho final prático onde serão trabalhados conceitos
# apresentados e exercitados em sala de aula.
#
# * Aspéctos como clareza e organização do código, comentários, raciocínio lógico, coerência no nome de variáveis, utilização das estruturas mais adequadas para a solução dos problemas e o funcionamento adequado serão analisados e irão compor o valor da nota final.
#
# * Procure entender exatamente o que se pede antes de iniciar a codificação. Quando se sabe o que é necessário fazer, a codificação fica mais fácil, mais eficiente e mais divertida ;-).
#
# * Faça o upload do notebook completo nomeado da seguinte forma: *nome_sobrenome_RA.ipynb*.
#
# * No caso de grupos, informar ao professor os membros de cada grupo e cada um deverá importar o arquivo no Canvas individualmente.
#
# * Arquivos com nomes incorretos serão desconsiderados!
#
# * Não deixem dúvidas para trás! Acessem os grupos combinados ou entrem em contato com o professor.
#
# ✌ Sucesso o/

# %% [markdown]
# # RMS Titanic
#
# O RMS Titanic foi um navio de passageiros britânico operado pela White Star Line e construído pelos estaleiros da Harland and Wolff em Belfast. Foi a segunda embarcação da Classe Olympic de transatlânticos depois do RMS Olympic e seguido pelo HMHS Britannic. Projetado pelos engenheiros navais Alexander Carlisle e Thomas Andrews, sua construção começou em março de 1909 e ele foi lançado ao mar em maio de 1911. O Titanic foi pensado para ser o navio mais luxuoso e mais seguro de sua época, gerando lendas que era supostamente "inafundável".
#
# A embarcação partiu em sua viagem inaugural de Southampton para Nova Iorque em 10 de abril de 1912, no caminho passando em Cherbourg-Octeville na França e por Queenstown na Irlanda. Ele colidiu com um iceberg às 23h40min do dia 14 de abril e afundou na madrugada do dia seguinte matando mais de 1500 pessoas, sendo um dos maiores desastres marítimos em tempos de paz de toda a história. Seu naufrágio destacou vários pontos fracos de seu projeto, deficiências nos procedimentos de evacuação de emergência e falhas nas regulamentações marítimas da época. Comissões de inquérito foram instauradas nos Estados Unidos e no Reino Unido, levando a mudanças nas leis internacionais de navegação que permanecem em vigor mais de um século depois.
#
# Os destroços do Titanic foram procurados por décadas até serem encontrados em 1985 por uma equipe liderada por Robert Ballard. Ele se encontra a 3843 m de profundidade e a 650 km ao sudeste de Terra Nova no Canadá. Sua história e naufrágio permaneceram no imaginário popular durante décadas, levando a produção de vários livros e filmes a seu respeito, mais notavelmente o filme Titanic de 1997. Até hoje o Titanic permanece como um dos navios mais famosos da história, com seus destroços atraindo várias expedições de exploração ao longo dos anos.
#
# *Fonte:* [WikiPedia](https://pt.wikipedia.org/wiki/RMS_Titanic)
#
# --------

# %% [markdown]
# A equipe da [Udacity](https://udacity.com) disponibilizou informações sobre uma parte dos passageiros à bordo do RMS Titanic no dia daquela tragédia. Esse _dataset_ que contém informações reais vem sendo utilizado em diversos estudos de caso, além de servir de base para aprendizado de Ciência de Dados, Estatística e Machine Learning.
#
# O arquivo **titanic_data.csv** contém informações reais sobre os passageiros organizadas da seguinte forma:
#
# - Survived (Sobreviveu): 0 = Não, 1 = Sim
# - Pclass (Classe): Classe de ingresso 1 = 1º, 2 = 2º, 3 = 3º
# - Sex (Sexo): Sexo do passageiro
# - Age (Idade): Idade em anos
# - Sibsp: Quantidade de irmãos / cônjuges a bordo do Titanic
# - Parch: Quantidade de pais / crianças a bordo do Titanic
# - Ticket (Bilhete): Número do bilhete de embarque
# - Fare (Tarifa): Tarifa paga pelo Passageiro
# - Cabin (Cabine): Número de cabine
# - Embarked (Embarque): Porto de Embarque (C = Cherbourg, Q = Queenstown, S = Southampton)
#
# O objetivo deste estudo é obter algumas informações estatísticas sobre a tragédia e realizar alguns _insights_ a respeito dos tripulantes e das circunstâncias do acidente.
#
# Efetue a carga do arquivo através da biblioteca _Pandas_ e a partir do _DataFrame_ gerado, efetue as operações necessárias para responder as questões.

# %% [markdown]
# ## Importando o DataSet

# %% [markdown]
# 1 - Efetuar a leitura do dataset através do Pandas, gerando um DataFrame de nome tit, levando-se em consideração que o arquivo encontra-se na mesma pasta do notebook.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

tit = pd.read_csv('/content/titanic_data.csv')

# %% [markdown]
# ## Conhecendo o DataSet

# %% [markdown]
# 2 - Quantas linhas e colunas tem o dataset? Quais os tipos das colunas?

# %%
tit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# 3 - Mostre os dados dos dez primeiros e 8 últimos registros do dataset.

# %%
tit.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
tit.tail(8)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# 883    male  28.0      0      0  C.A./SOTON 34068  10.500   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.050   NaN        S
# ...

# %% [markdown]
# 4 - Cálculos envolvendo colunas numéricas com dados faltantes podem sofrer impacto. É possível afirmar se há dados faltantes no dataset? Caso positivo, quais e quantos seriam esses dados? Preencha os dados faltantes de forma que não influenciem em operações futuras.

# %%
#Verificar valores NULOS
tit.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Substituir valores nulos
tit.fillna(0,inplace=True)

# %%
#Verificar valores NULOS
tit.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# ## Adequando o DataSet

# %% [markdown]
# 5 - Uma vez que algumas colunas não serão utilizadas, eventualmente é melhor excluí-las para que não interfiram na análise. Assim, exclua do dataset as colunas Sibsp, Parch e Ticket.

# %%
tit = tit.drop(columns=['SibSp','Parch','Ticket'])
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age     Fare  \
# 0                              Braund, Mr. Owen Harris    male  22.0   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0  71.2833
# 2                               Heikkinen, Miss. Laina  female  26.0   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0  53.1000
# 4                             Allen, Mr. William Henry    male  35.0   8.0500
# ...

# %% [markdown]
# 6 - Renomear as colunas restantes para a lingua portuguesa, utilizando os seguintes nomes de colunas: IdPassageiro, Sobreviveu, Classe, Nome, Sexo, Idade, Tarifa, Cabine e Embarque.

# %%
tit = tit.rename(columns=
           {'PassengerId':'IdPassageiro',
            'Survived':'Sobreviveu',
            'Pclass':'Classe',
            'Name':'Nome',
            'Sex':'Sexo',
            'Age':'Idade',
            'Fare':'Tarifa',
            'Cabin':'Cabine',
            'Embarked':'Embarque'
            })
tit
# Out:
#      IdPassageiro  Sobreviveu  Classe  \
# 0               1           0       3
# 1               2           1       1
# 2               3           1       3
# 3               4           1       1
# 4               5           0       3
# ..            ...         ...     ...
# 886           887           0       2
# 887           888           1       1
# 888           889           0       3
# 889           890           1       1
# 890           891           0       3
#
#                                                   Nome    Sexo  Idade  \
# 0                              Braund, Mr. Owen Harris    male   22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0
# 2                               Heikkinen, Miss. Laina  female   26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0
# 4                             Allen, Mr. William Henry    male   35.0
# ..                                                 ...     ...    ...
# ...

# %% [markdown]
# 7 - Alterar o conteudo da coluna Sobreviveu para:
# - 0 => Não
# - 1 => Sim

# %%
#Converter coluna Sobreviveu para string pois ao trocar o ZERO para NÃO, 
#o pandas entenderá q a coluna é do tipo Object e haverá um erro na troca do UM por SIM
tit['Sobreviveu'] = tit['Sobreviveu'].astype(str)
tit['Sobreviveu'] = np.where((tit['Sobreviveu']=='0'),'Não',tit['Sobreviveu'])
tit['Sobreviveu'] = np.where((tit['Sobreviveu']=='1'),'Sim',tit['Sobreviveu'])
tit.head(5)
# Out:
#    IdPassageiro Sobreviveu  Classe  \
# 0             1        Não       3
# 1             2        Sim       1
# 2             3        Sim       3
# 3             4        Sim       1
# 4             5        Não       3
#
#                                                 Nome    Sexo  Idade   Tarifa  \
# 0                            Braund, Mr. Owen Harris    male   22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38.0  71.2833
# 2                             Heikkinen, Miss. Laina  female   26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35.0  53.1000
# 4                           Allen, Mr. William Henry    male   35.0   8.0500
#
#   Cabine Embarque
# 0      0        S
# 1    C85        C
# 2      0        S
# 3   C123        S
# 4      0        S

# %% [markdown]
# 8 - Alterar o conteudo da coluna Sexo para:
# - female => Mulher
# - male   => Homem

# %%
tit['Sexo'] = np.where((tit['Sexo']=='female'),'Mulher',tit['Sexo'])
tit['Sexo'] = np.where((tit['Sexo']=='male'),'Homem',tit['Sexo'])
tit.head(5)
# Out:
#    IdPassageiro Sobreviveu  Classe  \
# 0             1        Não       3
# 1             2        Sim       1
# 2             3        Sim       3
# 3             4        Sim       1
# 4             5        Não       3
#
#                                                 Nome    Sexo  Idade   Tarifa  \
# 0                            Braund, Mr. Owen Harris   Homem   22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  Mulher   38.0  71.2833
# 2                             Heikkinen, Miss. Laina  Mulher   26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  Mulher   35.0  53.1000
# 4                           Allen, Mr. William Henry   Homem   35.0   8.0500
#
#   Cabine Embarque
# 0      0        S
# 1    C85        C
# 2      0        S
# 3   C123        S
# 4      0        S

# %% [markdown]
# ## Alguns números

# %% [markdown]
# 9 - Quantas mulheres e quantos homems estavam à bordo, de acordo com o dataset?

# %%
tit.groupby(['Sexo'])['Sexo'].count()
# Out:
# Sexo
# Homem     577
# Mulher    314
# Name: Sexo, dtype: int64

# %% [markdown]
# 10 - Quantos passageiros sobreviveram e quantos não sobreviveram?

# %%
tit.groupby(['Sobreviveu'])['Sobreviveu'].count()
# Out:
# Sobreviveu
# Não    549
# Sim    342
# Name: Sobreviveu, dtype: int64

# %%
aux = tit.groupby((['Sexo','Classe']))['Classe'].count().reset_index(name='Qtd')
labels = ['C1','C2','C3']
men_means = tit[(tit['Sexo']=='Homem')].groupby((['Sexo','Classe']))['Classe'].count().reset_index(name='Qtd')['Qtd']
women_means = tit[(tit['Sexo']=='Mulher')].groupby((['Sexo','Classe']))['Classe'].count().reset_index(name='Qtd')['Qtd']

x = np.arange(len(labels))  # the label locations
width = 0.25  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Homens',tick_label=labels)
rects2 = ax.bar(x + width/2,women_means, width, label='Mulheres',tick_label=labels)

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Quantidade de passageiros')
ax.set_xlabel('Classe de hospedagem')
ax.set_title('Quantidade de passageiros por sexo e classe de hospedagem')
ax.legend()


fig.tight_layout()

plt.show()

# %% [markdown]
# 11 - Quantas mulheres não sobreviveram?

# %%
tit[(tit['Sexo']=='Mulher')&(tit['Sobreviveu']=='Não')].groupby((['Sexo','Sobreviveu']))['Sobreviveu'].count().reset_index(name='Qtd')
# Out:
#      Sexo Sobreviveu  Qtd
# 0  Mulher        Não   81

# %% [markdown]
# 12 - Proporcionalmente, sobreviveram mais homens ou mais mulheres? Cite as proporções.

# %%
stat = tit.groupby((['Sexo','Sobreviveu']))['Sobreviveu'].count().reset_index(name='Qtd')

female = stat[stat['Sexo']=='Mulher']
femaleTotal = female['Qtd'].sum()
femaleSurvived = stat[(stat['Sexo']=='Mulher') & (stat['Sobreviveu']=='Sim')]['Qtd'].sum()
print(f'Mulheres Sobreviventes: {femaleSurvived}')
print(f'Total Mulheres: {femaleTotal}')
print(f'% sobrevivente: {round(femaleSurvived/femaleTotal,2)}')
# Out:
# Mulheres Sobreviventes: 233
# Total Mulheres: 314
# % sobrevivente: 0.74

# %%
maleTotal = stat[stat['Sexo']=='Homem']['Qtd'].sum()
maleSurvived = stat[(stat['Sexo']=='Homem') & (stat['Sobreviveu']=='Sim')]['Qtd'].sum()
print(f'Homens Sobreviventes: {maleSurvived}')
print(f'Total Homens: {maleTotal}')
print(f'% sobrevivente: {round(maleSurvived/maleTotal,2)}')
# Out:
# Homens Sobreviventes: 109
# Total Homens: 577
# % sobrevivente: 0.19

# %% [markdown]
# 13 - Levando-se em consideração a idade dos passageiros, qual a idade e quantidade de pessoas com o maior número de mortos?

# %%
#Desconsiderar Idade ZERO, pois o DataFrame foi preenchido com ZERO onde estava NULL
deadbyage = tit[(tit['Sobreviveu']=='Não')&(tit['Idade']>0)].groupby(['Idade'])['Idade'].count().sort_values(ascending=False).reset_index(name='Qtd')
deadbyage.head(10)
# Out:
#    Idade  Qtd
# 0   21.0   19
# 1   28.0   18
# 2   25.0   17
# 3   18.0   17
# 4   22.0   16
# 5   19.0   16
# 6   30.0   15
# 7   24.0   15
# 8   20.0   12
# 9   29.0   12

# %% [markdown]
# 14 - Qual a média de idade dos homens sobreviventes?

# %%
#Desconsiderar Idade ZERO, pois o DataFrame foi preenchido com ZERO onde estava NULL
averageAge = tit[(tit['Sobreviveu']=='Sim')&(tit['Idade']>0)&(tit['Sexo']=='Homem')]['Idade'].mean()
print(f'Média de idade dos homens sobreviventes: {round(averageAge,2)} anos')
# Out:
# Média de idade dos homens sobreviventes: 27.28 anos

# %% [markdown]
# 15 - Levando-se em consideração passageiros prioritários (mulheres e crianças de até 15 anos independente do sexo) qual a proporção de sobreviventes por sexo?

# %%
#Desconsiderar Idade ZERO, pois o DataFrame foi preenchido com ZERO onde estava NULL
#Filtrar todas as mulheres e crianças até 15 anos
priority = tit[((tit['Sexo']=='Mulher')|((tit['Idade']>0)&(tit['Idade']<15)))]
#Agrupar dados por Sexo e se Sobreviveu
priority = priority.groupby(['Sexo','Sobreviveu'])['Sobreviveu'].count().reset_index(name='Qtd')
#Fazendo um pivot table para facilitar os calculos e a apresentação
priority = priority.pivot(index='Sexo',columns=['Sobreviveu'],values='Qtd')
#Calcular o total de pessoas por sexo
priority['Total'] = priority['Não']+priority['Sim']
#Calcular % de sobreviventes
priority['% Sobreviventes'] = round(priority['Sim']/priority['Total']*100,2)
priority
# Out:
# Sobreviveu  Não  Sim  Total  % Sobreviventes
# Sexo
# Homem        18   21     39            53.85
# Mulher       81  233    314            74.20

# %% [markdown]
# 16 - Qual a quantidade de passageiros por classe?

# %%
tit.groupby(['Classe'])['Classe'].count().reset_index(name='Qtd')
# Out:
#    Classe  Qtd
# 0       1  216
# 1       2  184
# 2       3  491

# %% [markdown]
# 17 - Qual o percentual de sobreviventes por classe?

# %%
survivedClass = tit.groupby(['Classe','Sobreviveu'])['Classe'].count().reset_index(name='Qtd').pivot(index='Classe',columns='Sobreviveu',values='Qtd')

survivedClass['Total'] = survivedClass['Não'] + survivedClass['Sim']
survivedClass['% Sobreviventes'] = round(survivedClass['Sim']/survivedClass['Total']*100,2)
survivedClass
# Out:
# Sobreviveu  Não  Sim  Total  % Sobreviventes
# Classe
# 1            80  136    216            62.96
# 2            97   87    184            47.28
# 3           372  119    491            24.24

# %% [markdown]
# 18 - Crie um dataframe que demonstre a quantidade de sobreviventes e não sobreviventes, agrupados por sexo e classe.

# %%
df = tit.groupby(['Sexo','Classe','Sobreviveu'])['Sexo'].count().reset_index(name='Qtd')
df
# Out:
#       Sexo  Classe Sobreviveu  Qtd
# 0    Homem       1        Não   77
# 1    Homem       1        Sim   45
# 2    Homem       2        Não   91
# 3    Homem       2        Sim   17
# 4    Homem       3        Não  300
# 5    Homem       3        Sim   47
# 6   Mulher       1        Não    3
# 7   Mulher       1        Sim   91
# 8   Mulher       2        Não    6
# 9   Mulher       2        Sim   70
# 10  Mulher       3        Não   72
# 11  Mulher       3        Sim   72

# %% [markdown]
# 19 - Dos homens com idade entre 24 e 30 anos quantos da classe 3 sobreviveram? Quantos da classe 2 não sobreviveram?

# %%
mans = tit[((tit['Sexo']=='Homem')&(tit['Idade']>=24)&(tit['Idade']<=30))].groupby(['Classe','Sobreviveu'])['Classe'].count().reset_index(name='Qtd')
c3 = mans[(mans['Classe']==3)&(mans['Sobreviveu']=='Sim')]['Qtd'].sum()
print(f'Sobreviventes Classe 3: {c3}')

c2 = mans[(mans['Classe']==2)&(mans['Sobreviveu']=='Não')]['Qtd'].sum()
print(f'Não Sobreviventes Classe 2: {c2}')
# Out:
# Sobreviventes Classe 3: 12
# Não Sobreviventes Classe 2: 24

# %% [markdown]
# 20 - Calcule a probabilidade condicional de uma pessoa sobreviver, dado seu sexo e a classe em que estava viajando:
# - P(S= true | G=female,C=1)
# - P(S= true | G=female,C=2)
# - P(S= true | G=female,C=3)
# - P(S= true | G=male,C=1)
# - P(S= true | G=male,C=2)
# - P(S= true | G=male,C=3)

# %%
#Funcao para calculo de probabilidade de sobrevivencia dado o Sexo e a Classe de hospedagem
def prob(dados,condicoes):
  #Traduzir palavras
  condicoes = str.replace(condicoes,'true','Sim').replace('false','Não')
  condicoes = str.replace(condicoes,'female','Mulher').replace('male','Homem')
  #Segregar filtros
  a = str.replace(condicoes,'P(S= ','').replace(' | G=',',').replace('C=','').replace(')','').split(',')
  sobreviveu = str(a[0]) #Carregar filtro de sobrevivencia
  sexo = str(a[1]) #Carregar filtro de sexo
  classe = int(a[2])  #Carregar filtro de classe

  #Calculo do total da amostra
  totalAmostra = probs[(probs['Sexo']==sexo)]['Qtd'].sum()
  #Calculo do evento B (conhecido)
  eventoB = probs[(probs['Sexo']==sexo)&(probs['Classe']==classe)]['Qtd'].sum()
  #Calculo da probabilidade de B
  pb = eventoB / totalAmostra
  #Calculo do evento A 
  eventoA = probs[(probs['Sexo']==sexo)&(probs['Classe']==classe)&(probs['Sobreviveu']==sobreviveu)]['Qtd'].sum()
  #Calculo da probabilidade de ocorrer o evento A
  pa = eventoA / totalAmostra
  #Calculo da probabilidade de ocorrer o evento A dado evento B conhecido
  pab = round(pa/pb*100,2)
  print(f'{condicoes} = {pab}%')

# %%
#P(S|G,C)

probs = tit.groupby(['Sexo','Sobreviveu','Classe'])['Sexo'].count().reset_index(name='Qtd')
prob(probs,'P(S= true | G=female,C=1)')
prob(probs,'P(S= true | G=female,C=2)')
prob(probs,'P(S= true | G=female,C=3)')
prob(probs,'P(S= true | G=male,C=1)')
prob(probs,'P(S= true | G=male,C=2)')
prob(probs,'P(S= true | G=male,C=3)')
# Out:
# P(S= Sim | G=Mulher,C=1) = 96.81%
# P(S= Sim | G=Mulher,C=2) = 92.11%
# P(S= Sim | G=Mulher,C=3) = 50.0%
# P(S= Sim | G=Homem,C=1) = 36.89%
# P(S= Sim | G=Homem,C=2) = 15.74%
# P(S= Sim | G=Homem,C=3) = 13.54%

# %% [markdown]
# 21 - Distribuição da faixa etária e sexo

# %%
# Distribuição de passageiros Homem por idade
dist1 = tit[(tit['Sexo']=='Homem')&(tit['Idade']>0)]['Idade']
num_bins = 20

fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(dist1, num_bins)

ax.set_xlabel('Idade')
ax.set_ylabel('Quantidade de passageiros')
ax.set_title('Distribuição de passageiros Homens por idade')
# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.show()

# Distribuição de passageiras Mulher por idade
dist2 = tit[(tit['Sexo']=='Mulher')&(tit['Idade']>0)]['Idade']
num_bins = 20

fig, ax = plt.subplots()

# the histogram of the data
n, bins, patches = ax.hist(dist2, num_bins)

ax.set_xlabel('Idade')
ax.set_ylabel('Quantidade de passageiros')
ax.set_title('Distribuição de passageiras Mulher por idade')
# Tweak spacing to prevent clipping of ylabel
fig.tight_layout()
plt.show()
